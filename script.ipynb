# %%
import matplotlib.pyplot as plot
import cv2
from face_detector import getFacesBoundaries

imagePath = 'data/image4.jpeg'
cascPath = 'haarcascade_frontalface_default.xml'
faceCascade = cv2.CascadeClassifier(cascPath)

# %%
faces = getFacesBoundaries(imagePath, faceCascade)
plot.imshow(cv2.cvtColor(faces[0], cv2.COLOR_BGR2RGB))
